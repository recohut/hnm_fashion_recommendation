# %% [markdown]
# # Load Data

# %%
import pandas as pd

# %%
path = 'C:/Users/FT-LT74/hnm_fashion_recommendation/data/raw'

# %%
articles = pd.read_csv(path+'/articles.csv')
articles.head(5)
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# ...

# %%
articles.shape
# Out:
# (105542, 25)

# %%
customers = pd.read_csv(path+'/customers.csv')
customers.head(5)
# Out:
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
# 3             ACTIVE                   NONE  54.0
# 4             ACTIVE              Regularly  52.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# ...

# %%
customers.shape
# Out:
# (1371980, 7)

# %%
transactions = pd.read_csv(path+'/transactions_train.csv')

# %%
transactions.head(5)
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %%
transactions.shape
# Out:
# (31788324, 5)

# %% [markdown]
# # Exploring Data

# %%
articles.nunique()
# Out:
# article_id                      105542
# product_code                     47224
# prod_name                        45875
# product_type_no                    132
# product_type_name                  131
# product_group_name                  19
# graphical_appearance_no             30
# graphical_appearance_name           30
# colour_group_code                   50
# colour_group_name                   50
# perceived_colour_value_id            8
# perceived_colour_value_name          8
# perceived_colour_master_id          20
# perceived_colour_master_name        20
# department_no                      299
# department_name                    250
# index_code                          10
# index_name                          10
# index_group_no                       5
# index_group_name                     5
# section_no                          57
# section_name                        56
# garment_group_no                    21
# garment_group_name                  21
# ...

# %%
customers.nunique()
# Out:
# customer_id               1371980
# FN                              1
# Active                          1
# club_member_status              3
# fashion_news_frequency          4
# age                            84
# postal_code                352899
# dtype: int64

# %%
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  object
#  3   product_type_no               105542 non-null  int64
#  4   product_type_name             105542 non-null  object
#  5   product_group_name            105542 non-null  object
#  6   graphical_appearance_no       105542 non-null  int64
#  7   graphical_appearance_name     105542 non-null  object
#  8   colour_group_code             105542 non-null  int64
#  9   colour_group_name             105542 non-null  object
#  10  perceived_colour_value_id     105542 non-null  int64
#  11  perceived_colour_value_name   105542 non-null  object
# ...

# %% [markdown]
# detail_desc has NA/NULL values
#
# check for duplicated items/ typos?

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371980 entries, 0 to 1371979
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   customer_id             1371980 non-null  object
#  1   FN                      476930 non-null   float64
#  2   Active                  464404 non-null   float64
#  3   club_member_status      1365918 non-null  object
#  4   fashion_news_frequency  1355971 non-null  object
#  5   age                     1356119 non-null  float64
#  6   postal_code             1371980 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 73.3+ MB

# %% [markdown]
# all have NULL values besides customer_id and postal_code
#
# are there any addresses that are the same?

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31788324 entries, 0 to 31788323
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   t_dat             object
#  1   customer_id       object
#  2   article_id        int64
#  3   price             float64
#  4   sales_channel_id  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.2+ GB

# %% [markdown]
# # articles.csv

# %%
articles.head(1)
# Out:
#    article_id  product_code  prod_name  product_type_no product_type_name  \
# 0   108775015        108775  Strap top              253          Vest top
#
#    product_group_name  graphical_appearance_no graphical_appearance_name  \
# 0  Garment Upper body                  1010016                     Solid
#
#    colour_group_code colour_group_name  ...  department_name index_code  \
# 0                  9             Black  ...     Jersey Basic          A
#
#    index_name index_group_no  index_group_name section_no  \
# 0  Ladieswear              1        Ladieswear         16
#
#              section_name garment_group_no  garment_group_name  \
# 0  Womens Everyday Basics             1002        Jersey Basic
#
#                                detail_desc
# 0  Jersey top with narrow shoulder straps.
#
# [1 rows x 25 columns]

# %%
articles[articles['detail_desc'].isna()==True]
# Out:
#        article_id  product_code                   prod_name  product_type_no  \
# 1467    351332007        351332        Marshall Lace up Top              252
# 2644    420049002        420049                  OL TAGE PQ               87
# 2645    420049003        420049                  OL TAGE PQ               87
# 2742    426199002        426199  Ellen Shortie Daisy Low 3p              286
# 2743    426199010        426199  Ellen Shortie Daisy Low 3p              286
# ...           ...           ...                         ...              ...
# 67838   752458001        752458           Poissy boho dress              265
# 72720   768842001        768842                 Andrews set              270
# 72721   768842004        768842                 Andrews set              270
# 93144   856985001        856985                   Pogo rope               67
# 95624   867200001        867200              Necklace Simon               77
#
# ...

# %%
articles_count = articles['prod_name'].value_counts().to_frame().reset_index()

# %%
articles_count.head(5)
# Out:
#                    index  prod_name
# 0        Dragonfly dress         98
# 1               Mike tee         72
# 2   Wow printed tee 6.99         70
# 3                1pk Fun         55
# 4  TP Paddington Sweater         54

# %%
articles['article_id'].nunique()
# Out:
# 105542

# %%
articles.shape
# Out:
# (105542, 25)

# %%
articles[articles.iloc[:,1:].duplicated()]
# Out:
#         article_id  product_code                 prod_name  product_type_no  \
# 19       118458029        118458      Jerry jogger bottoms              272
# 45       145872053        145872          Dorian l/s basic              252
# 47       146706004        146706  Tanktop body white 3PACK              256
# 88       174057028        174057             FLEECE PYJAMA              295
# 91       174057032        174057             FLEECE PYJAMA              295
# ...            ...           ...                       ...              ...
# 104749   926603002        926603  Walnut 2-pack sport sock              302
# 104997   930032002        930032    Slouchy Mom fit belted              272
# 105060   931769004        931769      ED Madison Skinny HW              272
# 105286   936099002        936099    2p Penelope scrunchies               78
# 105447   942194002        942194          Magic Gloves New               71
#
# ...

# %%
articles[articles.prod_name.str.contains('Magic Gloves New')]  # sanity check
# Out:
#         article_id  product_code         prod_name  product_type_no  \
# 105446   942194001        942194  Magic Gloves New               71
# 105447   942194002        942194  Magic Gloves New               71
# 105448   942194004        942194  Magic Gloves New               71
#
#        product_type_name product_group_name  graphical_appearance_no  \
# 105446            Gloves        Accessories                  1010016
# 105447            Gloves        Accessories                  1010016
# 105448            Gloves        Accessories                  1010016
#
#        graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 105446                     Solid                  9             Black  ...
# 105447                     Solid                  9             Black  ...
# 105448                     Solid                 13             Beige  ...
#
#         department_name index_code  index_name index_group_no  \
# ...

# %% [markdown]
# ### Changing all to lowercase

# %%
# lowercase everything then check for duplication
for col in articles.columns:
    if articles[col].dtype == 'object':
        articles[col] = articles[col].str.lower()

# %%
articles.head(2)
# Out:
#    article_id  product_code  prod_name  product_type_no product_type_name  \
# 0   108775015        108775  strap top              253          vest top
# 1   108775044        108775  strap top              253          vest top
#
#    product_group_name  graphical_appearance_no graphical_appearance_name  \
# 0  garment upper body                  1010016                     solid
# 1  garment upper body                  1010016                     solid
#
#    colour_group_code colour_group_name  ...  department_name index_code  \
# 0                  9             black  ...     jersey basic          a
# 1                 10             white  ...     jersey basic          a
#
#    index_name index_group_no  index_group_name section_no  \
# 0  ladieswear              1        ladieswear         16
# 1  ladieswear              1        ladieswear         16
#
#              section_name garment_group_no  garment_group_name  \
# ...

# %% [markdown]
# ### Removing duplicates

# %%
articles_dup = articles[articles.iloc[:,1:].duplicated()]
articles_dup.head()
# Out:
#     article_id  product_code                 prod_name  product_type_no  \
# 19   118458029        118458      jerry jogger bottoms              272
# 45   145872053        145872          dorian l/s basic              252
# 47   146706004        146706  tanktop body white 3pack              256
# 88   174057028        174057             fleece pyjama              295
# 91   174057032        174057             fleece pyjama              295
#
#            product_type_name  product_group_name  graphical_appearance_no  \
# 19                  trousers  garment lower body                  1010010
# 45                   sweater  garment upper body                  1010010
# 47                  bodysuit  garment upper body                  1010016
# 88  pyjama jumpsuit/playsuit           nightwear                  1010001
# 91  pyjama jumpsuit/playsuit           nightwear                  1010001
#
#    graphical_appearance_name  colour_group_code colour_group_name  ...  \
# ...

# %%
articles_dup.shape
# Out:
# (5317, 25)

# %% [raw]
# articles[articles['prod_name'].str.contains('jerry jogger bottoms')]

# %%
article_dup_id = articles_dup['article_id'].to_list()

# %%
article_dup_id
# Out:
# [118458029,
#  145872053,
#  146706004,
#  174057028,
#  174057032,
#  174057033,
#  176209039,
#  176550020,
#  179950017,
#  186372045,
#  187949026,
#  187949028,
#  187949029,
#  187949030,
#  187949031,
#  187949032,
#  189616007,
#  189616008,
#  189616014,
#  189616015,
#  189616016,
#  189616032,
#  201219014,
#  204892029,
#  212629043,
#  212629047,
#  212629048,
#  212629051,
#  214844008,
#  215303005,
#  219075023,
#  224606031,
#  228257003,
#  233091021,
#  237347060,
#  237347069,
#  241486016,
#  243937028,
#  247072026,
#  247072032,
#  249136015,
#  249136020,
#  249136023,
#  249136025,
#  249136028,
#  254303056,
#  254457037,
#  254457038,
#  254457039,
#  255396024,
#  255396025,
#  255396042,
#  257430032,
#  257430036,
#  262277029,
#  265071027,
#  266875014,
#  269342023,
#  276242021,
#  276242025,
#  278038031,
#  278038035,
#  282832017,
#  282832018,
#  282832021,
#  287645029,
#  287645031,
#  288825018,
#  288825019,
#  288825024,
#  288859020,
# ...

# %%
articles2 = articles[~articles['article_id'].isin(article_dup_id)].reset_index()

# %%
articles2.drop(columns=['index'], inplace=True)

# %%
articles2
# Out:
#         article_id  product_code               prod_name  product_type_no  \
# 0        108775015        108775               strap top              253
# 1        108775044        108775               strap top              253
# 2        108775051        108775           strap top (1)              253
# 3        110065001        110065       op t-shirt (idro)              306
# 4        110065002        110065       op t-shirt (idro)              306
# ...            ...           ...                     ...              ...
# 100220   953450001        953450  5pk regular placement1              302
# 100221   953763001        953763       sport malaga tank              253
# 100222   956217002        956217         cartwheel dress              265
# 100223   957375001        957375        claire hair claw               72
# 100224   959461001        959461            lounge dress              265
#
#        product_type_name  product_group_name  graphical_appearance_no  \
# ...

# %% [markdown]
# ### Check for typos missed from duplicates

# %%
for col in articles.columns:
    if articles[col].dtype == 'object':
        print(col)
# Out:
# prod_name
# product_type_name
# product_group_name
# graphical_appearance_name
# colour_group_name
# perceived_colour_value_name
# perceived_colour_master_name
# department_name
# index_code
# index_name
# index_group_name
# section_name
# garment_group_name
# detail_desc

# %%
articles2['prod_name'].unique()
# Out:
# array(['strap top', 'strap top (1)', 'op t-shirt (idro)', ...,
#        'cartwheel dress', 'claire hair claw', 'lounge dress'],
#       dtype=object)

# %% [markdown]
# # customers.csv

# %%
customers
# Out:
#                                                customer_id   FN  Active  \
# 0        00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1        0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2        000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3        00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4        00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
# ...                                                    ...  ...     ...
# 1371975  ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e474...  NaN     NaN
# 1371976  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...  NaN     NaN
# 1371977  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...  1.0     1.0
# 1371978  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  1.0     1.0
# 1371979  ffffd9ac14e89946416d80e791d064701994755c3ab686...  NaN     NaN
#
#         club_member_status fashion_news_frequency   age  \
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371980 entries, 0 to 1371979
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   customer_id             1371980 non-null  object
#  1   FN                      476930 non-null   float64
#  2   Active                  464404 non-null   float64
#  3   club_member_status      1365918 non-null  object
#  4   fashion_news_frequency  1355971 non-null  object
#  5   age                     1356119 non-null  float64
#  6   postal_code             1371980 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 73.3+ MB

# %%
customers[customers['detail_desc'].isna()==True]

# %% [markdown]
# ### Check postal code

# %%
customers['postal_code'].value_counts()
# Out:
# 2c29ae653a9282cce4151bd87643c907644e09541abc28ae87dea0d1f6603b1c    120303
# cc4ed85e30f4977dae47662ddc468cd2eec11472de6fac5ec985080fd92243c8       261
# 714976379549eb90aae4a71bca6c7402cc646ae7c40f6c1cb91d4b5a18623fc1       159
# 7c1fa3b0ec1d37ce2c3f34f63bd792f3b4494f324b6be5d1e4ba6a75456b96a7       157
# 5b7eb31eabebd3277de632b82267286d847fd5d44287ee150bb4206b48439145       156
#                                                                      ...
# 2a86cf60e8a2e8d8e42d8b573ac8352f02acf30feaaf4da7d8ce890e2cf351c8         1
# d2f8a4cda6064a9f12a195cefbe03b9f06a087ef56ed1747b61d598267b639b8         1
# 37f8fd38f5be92e572c198afa71bd4cba7c378923997f5615360a9f2f424803f         1
# db6db465630f871f2f9c9840d57d9fae1286de09d6da241eb63db8750a621ff1         1
# 9852205ad29464af994ad5289e91a5a86bcda3a91ed2187e83000aca1825749c         1
# Name: postal_code, Length: 352899, dtype: int64

# %%
customers[]
